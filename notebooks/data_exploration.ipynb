# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/email.csv')

# %%
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.describe()
# Out:
#        Category                 Message
# count      5573                    5573
# unique        3                    5158
# top         ham  Sorry, I'll call later
# freq       4825                      30

# %%
df.shape
# Out:
# (5573, 2)

# %%
df.dtypes
# Out:
# Category    str
# Message     str
# dtype: object

# %%
df.isna().sum()
# Out:
# Category    0
# Message     0
# dtype: int64

# %%
df[df['Category'] == '{"mode":"full"']
# Out:
#             Category          Message
# 5572  {"mode":"full"  isActive:false}

# %%
df['Category'].unique()
# Out:
# <ArrowStringArray>
# ['ham', 'spam', '{"mode":"full"']
# Length: 3, dtype: str

# %%
df[df['Category'] != 'ham'][df['Category'] != 'spam']
# Out:
# /tmp/ipykernel_11585/1458601964.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Category'] != 'ham'][df['Category'] != 'spam']
#             Category          Message
# 5572  {"mode":"full"  isActive:false}

# %% [markdown]
# ### Notes

# %% [markdown]
# #### Row 5572 needs to be removed
